# %%
import pandas as pd

# %%
base_path = "C:/Users/31155/Dropbox/EV-GasDualNetwork/Data/raw/全国加油站加气站数据"

# %%
CS_dir = f"{base_path}/充电站"
GS_dir = f"{base_path}/加油站加气站"
CSGS_dir = f"{base_path}/加油站加气站充电站一起的"

CS_dir_example = CS_dir + "/全国加油站加气站数据2016_充电站.csv"
GS_dir_example = GS_dir + "/全国加油站加气站数据2016_加油站加气站.csv"
CSGS_dir_example = CSGS_dir + "/全国加油站加气站数据2016.csv"

CS_data_example = pd.read_csv(CS_dir_example)
GS_data_example = pd.read_csv(GS_dir_example)
CSGS_data_example = pd.read_csv(CSGS_dir_example)

# %%
CS_data_example
# Out:
#                   name                    address     wgs84_x    wgs84_y  \
# 0               特斯拉充电站               深南大道9028号3附近  113.975639  22.537855
# 1         力能加电站(科苑南站店)                  高新南十一道11号  113.946419  22.524179
# 2                  充电站                    国庆西路9附近  117.004349  32.643238
# 3     江苏省电力公司电动汽车板闸充电站                    237省道附近  119.121216  33.556835
# 4         淮安六洞服务区汽车充电站                             119.263802  33.423424
# ...                ...                        ...         ...        ...
# 2087     特斯拉充电站(博林天瑞站)                   西丽留仙大道以北  113.954453  22.577459
# 2088   特斯拉充电站(水湾1979站)  兴华路6号南海意库5号楼40深圳市成品地产有限公司  113.917274  22.485844
# 2089     中国南方电网电动汽车充电桩                  前海路321号附近  113.896515  22.501659
# 2090    中国普天力能加电站(南头站)                     深南大道附近  113.913811  22.543032
# 2091    奥特迅汽车充电站(松坪山站)                   松坪山路3号附近  113.952011  22.554688
#
#               tel pname cityname adname    大类   中类   小类
# ...

# %%
GS_data_example
# Out:
#                       name         address     wgs84_x    wgs84_y  \
# 0                 月亮湾大道加油站         月亮湾大道附近  113.878723  22.492744
# 1                中国石化侨城加油站       深南大道9006号  113.994072  22.533737
# 2       广东深圳龙珠源加油站(怡然天地居东)         龙珠大道37号  113.976372  22.562506
# 3                  深南燃气加气站       南山大道3039号  113.922997  22.546974
# 4             中国石油鹏正兴南园加油站        南新路1040号  113.916954  22.516178
# ...                    ...             ...         ...        ...
# 120025     深圳燃气集团汽车加气站松坪山站           宝深路附近  113.946648  22.560846
# 120026       中国石油加油站(妈湾大道)       妈湾大道120附近  113.871445  22.504406
# 120027              花园路加油站  南海大道1084-1086号  113.922752  22.501451
# 120028           中国石化鹏顺源油站        大板桥巷26附近  113.915535  22.524401
# 120029         中国石化龙珠油气合建站         龙珠大道80号  113.972763  22.565710
#
#                                 tel pname cityname adname    大类   中类    小类
# 0                                     广东省      深圳市    南山区  汽车服务  加油站   加油站
# ...

# %%
CSGS_data_example
# Out:
#                       name         address     wgs84_x    wgs84_y  \
# 0                 月亮湾大道加油站         月亮湾大道附近  113.878723  22.492744
# 1                中国石化侨城加油站       深南大道9006号  113.994072  22.533737
# 2                   特斯拉充电站    深南大道9028号3附近  113.975639  22.537855
# 3       广东深圳龙珠源加油站(怡然天地居东)         龙珠大道37号  113.976372  22.562506
# 4                  深南燃气加气站       南山大道3039号  113.922997  22.546974
# ...                    ...             ...         ...        ...
# 122117              花园路加油站  南海大道1084-1086号  113.922752  22.501451
# 122118           中国石化鹏顺源油站        大板桥巷26附近  113.915535  22.524401
# 122119      中国普天力能加电站(南头站)          深南大道附近  113.913811  22.543032
# 122120         中国石化龙珠油气合建站         龙珠大道80号  113.972763  22.565710
# 122121      奥特迅汽车充电站(松坪山站)        松坪山路3号附近  113.952011  22.554688
#
#                                 tel pname cityname adname    大类   中类    小类
# 0                                     广东省      深圳市    南山区  汽车服务  加油站   加油站
# ...
